# %%
import pandas as pd
import numpy as np

# %%
customers = pd.read_csv('D:/Self-learning/Project/Dataset/raw/olist_customers_dataset.csv')
geolocation = pd.read_csv('D:/Self-learning/Project/Dataset/raw/olist_geolocation_dataset.csv')
order_items = pd.read_csv('D:/Self-learning/Project/Dataset/raw/olist_order_items_dataset.csv')
order_payments = pd.read_csv('D:/Self-learning/Project/Dataset/raw/olist_order_payments_dataset.csv')
order_reviews = pd.read_csv('D:/Self-learning/Project/Dataset/raw/olist_order_reviews_dataset.csv')
orders = pd.read_csv('D:/Self-learning/Project/Dataset/raw/olist_orders_dataset.csv')
products = pd.read_csv('D:/Self-learning/Project/Dataset/raw/olist_products_dataset.csv')
sellers = pd.read_csv('D:/Self-learning/Project/Dataset/raw/olist_sellers_dataset.csv')
translation = pd.read_csv('D:/Self-learning/Project/Dataset/raw/product_category_name_translation.csv')

# %% [markdown]
# # **`All Dataset`**

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
translation.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
data_dictionary = pd.DataFrame({
    'Dataset':[
        'customers',
        'orders',
        'products',
        'order_items',
        'order_payments',
        'order_reviews',
        'sellers',
        'geolocation',
        'translation'
    ],
    'Primary Key':[
        'customer_id',
        'order_id',
        'product_id',
        '(order_id,order_item_id)',
        'order_id',
        'review_id',
        'seller_id',
        'No PK',
        'No PK'
    ]
})

data_dictionary
# Out:
#           Dataset               Primary Key
# 0       customers               customer_id
# 1          orders                  order_id
# 2        products                product_id
# 3     order_items  (order_id,order_item_id)
# 4  order_payments                  order_id
# 5   order_reviews                 review_id
# 6         sellers                 seller_id
# 7     geolocation                     No PK
# 8     translation                     No PK

# %%
data_dictionary.to_excel(
    'D:/Self-learning/Project/Dataset/cleaned/data_dictionary.xlsx',
    index=False
)

# %% [markdown]
# # **`Customer Dataset`**

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  str
#  1   customer_unique_id        99441 non-null  str
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  str
#  4   customer_state            99441 non-null  str
# dtypes: int64(1), str(4)
# memory usage: 3.8 MB

# %%
customers.nunique()
# Out:
# customer_id                 99441
# customer_unique_id          96096
# customer_zip_code_prefix    14994
# customer_city                4119
# customer_state                 27
# dtype: int64

# %%
customers.isna().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers['customer_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
customers['customer_city'].value_counts()
# Out:
# customer_city
# sao paulo              15540
# rio de janeiro          6882
# belo horizonte          2773
# brasilia                2131
# curitiba                1521
#                        ...
# siriji                     1
# natividade da serra        1
# monte bonito               1
# sao rafael                 1
# eugenio de castro          1
# Name: count, Length: 4119, dtype: int64

# %%
customers['customer_state'].value_counts()
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: count, dtype: int64

# %%
customers['customer_zip_code_prefix'].nunique()
# Out:
# 14994

# %%
customers['customer_unique_id'].value_counts()
# Out:
# customer_unique_id
# 8d50f5eadf50201ccdcedfb9e2ac8455    17
# 3e43e6105506432c953e165fb2acf44c     9
# 1b6c7548a2a1f9037c1fd3ddfed95f33     7
# 6469f99c1f9dfae7733b25662e7f1782     7
# ca77025e7201e3b30c44b472ff346268     7
#                                     ..
# 1a29b476fee25c95fbafc67c5ac95cf8     1
# d52a67c98be1cf6a5c84435bd38d095d     1
# e9f50caf99f032f0bf3c55141f019d99     1
# 73c2643a0a458b49f58cea58833b192e     1
# 84732c5050c01db9b23e19ba39899398     1
# Name: count, Length: 96096, dtype: int64

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  str
#  1   customer_unique_id        99441 non-null  str
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  str
#  4   customer_state            99441 non-null  str
# dtypes: int64(1), str(4)
# memory usage: 3.8 MB

# %%
customers.boxplot('customer_zip_code_prefix')
# Out:
# <Axes: >

# %% [markdown]
# # **`Orders Dataset`**

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders.shape
# Out:
# (99441, 8)

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  str
#  4   order_approved_at              99281 non-null  str
#  5   order_delivered_carrier_date   97658 non-null  str
#  6   order_delivered_customer_date  96476 non-null  str
#  7   order_estimated_delivery_date  99441 non-null  str
# dtypes: str(8)
# memory usage: 6.1 MB

# %%
orders.nunique()
# Out:
# order_id                         99441
# customer_id                      99441
# order_status                         8
# order_purchase_timestamp         98875
# order_approved_at                90733
# order_delivered_carrier_date     81018
# order_delivered_customer_date    95664
# order_estimated_delivery_date      459
# dtype: int64

# %%
orders.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
round(orders.isna().mean(),2)
# Out:
# order_id                         0.00
# customer_id                      0.00
# order_status                     0.00
# order_purchase_timestamp         0.00
# order_approved_at                0.00
# order_delivered_carrier_date     0.02
# order_delivered_customer_date    0.03
# order_estimated_delivery_date    0.00
# dtype: float64

# %%
orders.groupby('order_status').agg({
    'order_approved_at':'count',
    'order_delivered_carrier_date':'count',
    'order_delivered_customer_date':'count'
})
# Out:
#               order_approved_at  order_delivered_carrier_date  \
# order_status
# approved                      2                             0
# canceled                    484                            75
# created                       0                             0
# delivered                 96464                         96476
# invoiced                    314                             0
# processing                  301                             0
# shipped                    1107                          1107
# unavailable                 609                             0
#
#               order_delivered_customer_date
# order_status
# approved                                  0
# canceled                                  6
# created                                   0
# delivered                             96470
# invoiced                                  0
# processing                                0
# shipped                                   0
# ...

# %%
orders['order_status'].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders['order_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
orders['customer_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders['order_status'].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  str
#  4   order_approved_at              99281 non-null  str
#  5   order_delivered_carrier_date   97658 non-null  str
#  6   order_delivered_customer_date  96476 non-null  str
#  7   order_estimated_delivery_date  99441 non-null  str
# dtypes: str(8)
# memory usage: 6.1 MB

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders['order_purchase_timestamp']= pd.to_datetime(orders['order_purchase_timestamp'])
orders['order_approved_at']= pd.to_datetime(orders['order_approved_at'])
orders['order_delivered_carrier_date']= pd.to_datetime(orders['order_delivered_carrier_date'])
orders['order_delivered_customer_date']= pd.to_datetime(orders['order_delivered_customer_date'])
orders['order_estimated_delivery_date']= pd.to_datetime(orders['order_estimated_delivery_date'])

orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  datetime64[us]
#  4   order_approved_at              99281 non-null  datetime64[us]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[us]
#  6   order_delivered_customer_date  96476 non-null  datetime64[us]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[us]
# dtypes: datetime64[us](5), str(3)
# memory usage: 6.1 MB

# %%
orders['delivery_days'] = (
    orders['order_delivered_customer_date']
    - orders['order_purchase_timestamp']
).dt.days

# %%
orders['estimate_delivery_days']= (
    orders['order_estimated_delivery_date']
    - orders['order_purchase_timestamp']
).dt.days

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders['approval_hours'] = (
    orders['order_approved_at']
    -
    orders['order_purchase_timestamp']
).dt.total_seconds()/3600

# %%
orders['carrier_pickup_days'] = (
    orders['order_delivered_carrier_date']
    -
    orders['order_approved_at']
).dt.days

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders['late_delivery'] = np.where(
    orders['order_status'] != 'delivered',
    None,
    np.where(
        orders['order_delivered_customer_date'] >
        orders['order_estimated_delivery_date'],
        'Late',
        'On Time'
    )
)

# %%
orders['late_delivery'].value_counts(dropna=False)
# Out:
# late_delivery
# On Time    88652
# Late        7826
# NaN         2963
# Name: count, dtype: int64

# %%
orders['delivery_variance_days'] = (
    orders['order_delivered_customer_date']
    -
    orders['order_estimated_delivery_date']
).dt.days

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders['late_delivery'].value_counts()
# Out:
# late_delivery
# On Time    88652
# Late        7826
# Name: count, dtype: int64

# %%
orders[orders['delivery_days'] < 0]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, delivery_days, estimate_delivery_days, approval_hours, carrier_pickup_days, late_delivery, delivery_variance_days]
# Index: []

# %%
orders[orders['approval_hours'] < 0]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date, delivery_days, estimate_delivery_days, approval_hours, carrier_pickup_days, late_delivery, delivery_variance_days]
# Index: []

# %%
orders[orders['carrier_pickup_days'] < 0]
# Out:
#                                order_id                       customer_id  \
# 15     dcb36b511fcac050b97cd5c05de84dc3  3b6828a50ffe546942b7a473d70ac0fc
# 64     688052146432ef8253587b930b01a06d  81e08b08e5ed4472008030d70327c71f
# 199    58d4c4747ee059eeeb865b349b41f53a  1755fad7863475346bc6c3773fe055d3
# 210    412fccb2b44a99b36714bca3fef8ad7b  c6865c523687cb3f235aa599afef1710
# 415    56a4ac10a4a8f2ba7693523bb439eede  78438ba6ace7d2cb023dbbc81b083562
# ...                                 ...                               ...
# 99091  240ead1a7284667e0ec71d01f80e4d5e  fcdd7556401aaa1c980f8b67a69f95dc
# 99230  78008d03bd8ef7fcf1568728b316553c  043e3254e68daf7256bda1c9c03c2286
# 99266  76a948cd55bf22799753720d4545dd2d  3f20a07b28aa252d0502fe7f7eb030a9
# 99377  a6bd1f93b7ff72cc348ca07f38ec4bee  6d63fa86bd2f62908ad328325799152f
# 99406  7fd85cb0143de098a4c5ab5a57bfbd91  d32034dfc685b1ae15dd4c78eace868e
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %% [markdown]
# approval_date = July 27
# carrier_pickup = July 24
#
#     Carrier cannot receive the package before approval.
#
# This indicates data quality issues.

# %%
orders['pickup_date_issue'] = np.where(
    orders['carrier_pickup_days'] < 0,
    1,
    0
)

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders['pickup_date_issue'].value_counts()
# Out:
# pickup_date_issue
# 0    98082
# 1     1359
# Name: count, dtype: int64

# %%
orders['order_status'].value_counts()
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
orders['order_status'].value_counts(normalize=True)*100
# Out:
# order_status
# delivered      97.020344
# shipped         1.113223
# canceled        0.628513
# unavailable     0.612423
# invoiced        0.315765
# processing      0.302692
# created         0.005028
# approved        0.002011
# Name: proportion, dtype: float64

# %%
delivered_orders = orders[
    orders['order_status'] == 'delivered'
]

# %%
delivered_orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
delivered_orders['delivery_days'].describe()
# Out:
# count    96470.000000
# mean        12.093604
# std          9.551380
# min          0.000000
# 25%          6.000000
# 50%         10.000000
# 75%         15.000000
# max        209.000000
# Name: delivery_days, dtype: float64

# %%
delivered_orders['delivery_variance_days'].describe()
# Out:
# count    96470.000000
# mean       -11.875889
# std         10.182105
# min       -147.000000
# 25%        -17.000000
# 50%        -12.000000
# 75%         -7.000000
# max        188.000000
# Name: delivery_variance_days, dtype: float64

# %%
orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# delivery_days                    2965
# estimate_delivery_days              0
# approval_hours                    160
# carrier_pickup_days              1797
# late_delivery                    2963
# delivery_variance_days           2965
# pickup_date_issue                   0
# dtype: int64

# %% [markdown]
# # **`Products Dataset`**

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  str
#  1   product_category_name       32341 non-null  str
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), str(2)
# memory usage: 2.3 MB

# %%
products.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
round(products.isna().mean(),2)
# Out:
# product_id                    0.00
# product_category_name         0.02
# product_name_lenght           0.02
# product_description_lenght    0.02
# product_photos_qty            0.02
# product_weight_g              0.00
# product_length_cm             0.00
# product_height_cm             0.00
# product_width_cm              0.00
# dtype: float64

# %%
products.boxplot('product_name_lenght')
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

for i in products.select_dtypes("number").columns:
  products.boxplot(column=i)
  plt.show()

# %%
products['product_category_name'] = products['product_category_name'].fillna('Unknown')

# %%
products.isna().sum()
# Out:
# product_id                      0
# product_category_name           0
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
na_columns = ['product_name_lenght',
              'product_description_lenght',
              'product_photos_qty',
              'product_weight_g',
              'product_length_cm'	,
              'product_height_cm'	,
              'product_width_cm'
            ]

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median')
products[na_columns] = imputer.fit_transform(products[na_columns])

# %%
products.duplicated().sum()
# Out:
# np.int64(0)

# %%
products['product_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
products.value_counts()
# Out:
# product_id                        product_category_name              product_name_lenght  product_description_lenght  product_photos_qty  product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 1e9e8ef04dbcff4541ed26657ea517e5  perfumaria                         40.0                 287.0                       1.0                 225.0             16.0               10.0               14.0                1
# 3aa071139cb16b67ca9e5dea641aaa2f  artes                              44.0                 276.0                       1.0                 1000.0            30.0               18.0               20.0                1
# 96bd76ec8810374ed1b65e291975717f  esporte_lazer                      46.0                 250.0                       1.0                 154.0             18.0               9.0                15.0                1
# ...

# %%
for i in products.select_dtypes("number").columns:
  products.boxplot(column=i)
  plt.show()

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
products['product_volume_cm'] = (
    products['product_length_cm']
    *
    products['product_height_cm']
    *
    products['product_width_cm']
)

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# # **`Sellers Dataset`**

# %%
sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
sellers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   str
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   str
#  3   seller_state            3095 non-null   str
# dtypes: int64(1), str(3)
# memory usage: 96.8 KB

# %%
sellers.isna().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %%
sellers.duplicated().sum()
# Out:
# np.int64(0)

# %%
sellers['seller_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
sellers.nunique()
# Out:
# seller_id                 3095
# seller_zip_code_prefix    2246
# seller_city                611
# seller_state                23
# dtype: int64

# %% [markdown]
# # **`Order Item Dataset`**

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_items.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  str
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  str
#  3   seller_id            112650 non-null  str
#  4   shipping_limit_date  112650 non-null  str
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), str(4)
# memory usage: 6.0 MB

# %%
order_items.isna().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
order_items.duplicated().sum()
# Out:
# np.int64(0)

# %%
order_items['order_id'].duplicated().sum()
# Out:
# np.int64(13984)

# %%
order_items['order_item_id'].duplicated().sum()
# Out:
# np.int64(112629)

# %%
order_items['product_id'].duplicated().sum()
# Out:
# np.int64(79699)

# %%
order_items['seller_id'].duplicated().sum()
# Out:
# np.int64(109555)

# %%
order_items.nunique()
# Out:
# order_id               98666
# order_item_id             21
# product_id             32951
# seller_id               3095
# shipping_limit_date    93318
# price                   5968
# freight_value           6999
# dtype: int64

# %%
order_items['shipping_limit_date']=pd.to_datetime(order_items['shipping_limit_date'])

# %%
order_items.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  str
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  str
#  3   seller_id            112650 non-null  str
#  4   shipping_limit_date  112650 non-null  datetime64[us]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[us](1), float64(2), int64(1), str(3)
# memory usage: 6.0 MB

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0 2017-09-19 09:45:35   58.90          13.29
# 1 2017-05-03 11:05:13  239.90          19.93
# 2 2018-01-18 14:48:30  199.00          17.87
# 3 2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_items['order_item_id'].duplicated().sum()
# Out:
# np.int64(112629)

# %%
order_items.describe()
# Out:
#        order_item_id         shipping_limit_date          price  freight_value
# count  112650.000000                      112650  112650.000000  112650.000000
# mean        1.197834  2018-01-07 15:36:52.192685     120.653739      19.990320
# min         1.000000         2016-09-19 00:15:34       0.850000       0.000000
# 25%         1.000000  2017-09-20 20:57:27.500000      39.900000      13.080000
# 50%         1.000000         2018-01-26 13:59:35      74.990000      16.260000
# 75%         1.000000  2018-05-10 14:34:00.750000     134.900000      21.150000
# max        21.000000         2020-04-09 22:35:08    6735.000000     409.680000
# std         0.705124                         NaN     183.633928      15.806405

# %%
order_items.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  str
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  str
#  3   seller_id            112650 non-null  str
#  4   shipping_limit_date  112650 non-null  datetime64[us]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[us](1), float64(2), int64(1), str(3)
# memory usage: 6.0 MB

# %%
for i in order_items.select_dtypes("number").columns:
  order_items.boxplot(column=i)
  plt.show()

# %%
order_items.sort_values(
    'price',
    ascending=False
).head(20)
# Out:
#                                 order_id  order_item_id  \
# 3556    0812eb902a67711a1cb742b3cdaa65ae              1
# 112233  fefacc66af859508bf1a7934eab1e97f              1
# 107841  f5136e38d1a14a4dbd87dff67da82701              1
# 74336   a96610ab360d42a2e5335a3998b4718a              1
# 11249   199af31afc78c699f0dbf71fb178d4d4              1
# 62086   8dbc85d1447242f3b127dda390d56e19              1
# 29193   426a9742b533fc6fed17d1fd6d143d7e              1
# 45843   68101694e5c5dc7330c91e1bbc36214f              1
# 78310   b239ca7cd485940b31882363b52e6674              1
# 59137   86c4eab1571921a6a6e248ed312f5a5a              1
# 56663   80dfedb6d17bf23539beeef3c768f4d7              1
# 67456   9a3966c23190dbdbaabed08e8429c006              1
# 28884   41b7766bb1df487d17fb9725b78ff509              1
# 69142   9de73f3e6157169ad6c32b9f313c7dcb              1
# 93516   d3f66901a6743e15f9311547cc623b91              1
# 102349  e85c92ee6a3ba1ef47e41c23286314d9              1
# ...

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value
# 0 2017-09-19 09:45:35   58.90          13.29
# 1 2017-05-03 11:05:13  239.90          19.93
# 2 2018-01-18 14:48:30  199.00          17.87
# 3 2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_items['order_value']= (
    order_items['price']
    +
    order_items['freight_value'])

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  order_value
# 0 2017-09-19 09:45:35   58.90          13.29        72.19
# 1 2017-05-03 11:05:13  239.90          19.93       259.83
# 2 2018-01-18 14:48:30  199.00          17.87       216.87
# ...

# %%
order_items['profit'] = (
    order_items['price']
    -
    (order_items['price'] * 0.60)
    -
    order_items['freight_value']
)

# %%
order_items['profit_margin'] = (
    order_items['profit']
    /
    order_items['price']
) * 100

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  order_value  profit  \
# 0 2017-09-19 09:45:35   58.90          13.29        72.19  10.270
# 1 2017-05-03 11:05:13  239.90          19.93       259.83  76.030
# ...

# %% [markdown]
# # **`Order Reviews Dataset`**

# %%
order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
order_reviews.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  str
#  1   order_id                 99224 non-null  str
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  str
#  4   review_comment_message   40977 non-null  str
#  5   review_creation_date     99224 non-null  str
#  6   review_answer_timestamp  99224 non-null  str
# dtypes: int64(1), str(6)
# memory usage: 5.3 MB

# %%
order_reviews.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
round(order_reviews.isna().mean(),2)
# Out:
# review_id                  0.00
# order_id                   0.00
# review_score               0.00
# review_comment_title       0.88
# review_comment_message     0.59
# review_creation_date       0.00
# review_answer_timestamp    0.00
# dtype: float64

# %%
order_reviews['review_comment_title']=order_reviews['review_comment_title'].fillna('Unknown')
order_reviews['review_comment_message']=order_reviews['review_comment_message'].fillna('Unknown')

# %%
order_reviews.duplicated().sum()
# Out:
# np.int64(0)

# %%
order_reviews['review_id'].duplicated().sum()
# Out:
# np.int64(814)

# %%
order_reviews['order_id'].duplicated().sum()
# Out:
# np.int64(551)

# %%
order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4              Unknown
# 1             5              Unknown
# 2             5              Unknown
# 3             5              Unknown
# 4             5              Unknown
#
#                               review_comment_message review_creation_date  \
# 0                                            Unknown  2018-01-18 00:00:00
# 1                                            Unknown  2018-03-10 00:00:00
# 2                                            Unknown  2018-02-17 00:00:00
# ...

# %%
order_reviews.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  str
#  1   order_id                 99224 non-null  str
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     99224 non-null  str
#  4   review_comment_message   99224 non-null  str
#  5   review_creation_date     99224 non-null  str
#  6   review_answer_timestamp  99224 non-null  str
# dtypes: int64(1), str(6)
# memory usage: 5.3 MB

# %%
order_reviews['review_creation_date']=pd.to_datetime(order_reviews['review_creation_date'])
order_reviews['review_answer_timestamp']=pd.to_datetime(order_reviews['review_answer_timestamp'])

# %%
order_reviews['review_score'].value_counts()
# Out:
# review_score
# 5    57328
# 4    19142
# 1    11424
# 3     8179
# 2     3151
# Name: count, dtype: int64

# %%
order_reviews.boxplot('review_score')
# Out:
# <Axes: >

# %%
order_reviews.describe()
# Out:
#        review_score        review_creation_date     review_answer_timestamp
# count  99224.000000                       99224                       99224
# mean       4.086421  2018-01-12 20:49:23.948238  2018-01-16 00:23:56.977939
# min        1.000000         2016-10-02 00:00:00         2016-10-07 18:32:28
# 25%        4.000000         2017-09-23 00:00:00  2017-09-27 01:53:27.250000
# 50%        5.000000         2018-02-02 00:00:00  2018-02-04 22:41:47.500000
# 75%        5.000000         2018-05-16 00:00:00  2018-05-20 12:11:21.500000
# max        5.000000         2018-08-31 00:00:00         2018-10-29 12:27:35
# std        1.347579                         NaN                         NaN

# %%
order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4              Unknown
# 1             5              Unknown
# 2             5              Unknown
# 3             5              Unknown
# 4             5              Unknown
#
#                               review_comment_message review_creation_date  \
# 0                                            Unknown           2018-01-18
# 1                                            Unknown           2018-03-10
# 2                                            Unknown           2018-02-17
# ...

# %%
order_reviews['review_response_days'] = (
    order_reviews['review_answer_timestamp']
    -
    order_reviews['review_creation_date']
).dt.days

# %%
order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4              Unknown
# 1             5              Unknown
# 2             5              Unknown
# 3             5              Unknown
# 4             5              Unknown
#
#                               review_comment_message review_creation_date  \
# 0                                            Unknown           2018-01-18
# 1                                            Unknown           2018-03-10
# 2                                            Unknown           2018-02-17
# ...

# %% [markdown]
# # **`Order Payments Dataset`**

# %%
order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_payments.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  str
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  str
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), str(2)
# memory usage: 4.0 MB

# %%
order_payments.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
order_payments.duplicated().sum()
# Out:
# np.int64(0)

# %%
order_payments['order_id'].duplicated().sum()
# Out:
# np.int64(4446)

# %%
order_payments['payment_sequential'].value_counts()
# Out:
# payment_sequential
# 1     99360
# 2      3039
# 3       581
# 4       278
# 5       170
# 6       118
# 7        82
# 8        54
# 9        43
# 10       34
# 11       29
# 12       21
# 13       13
# 14       10
# 15        8
# 17        6
# 19        6
# 16        6
# 18        6
# 21        4
# 20        4
# 22        3
# 25        2
# 26        2
# 24        2
# 23        2
# 27        1
# 29        1
# 28        1
# Name: count, dtype: int64

# %%
order_payments['payment_type'].value_counts()
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %% [markdown]
# delete the not define payment type

# %%
order_payments[order_payments['payment_type']!='not_defined']
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
order_payments= order_payments[order_payments['payment_type']!='not_defined']

# %%
order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_payments.groupby('order_id').size().describe()
# Out:
# count    99437.000000
# mean         1.044712
# std          0.381171
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         29.000000
# dtype: float64

# %%
for i in order_payments.select_dtypes("number").columns:
  order_payments.boxplot(column=i)
  plt.show()

# %%
order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_payments['payment_type'].value_counts()
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# Name: count, dtype: int64

# %%
order_payments['payment_group'] = np.where(
    order_payments['payment_type'] == 'credit_card',
    'Card',
    'Non Card'
)

# %%
order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value payment_group
# 0                     8          99.33          Card
# 1                     1          24.39          Card
# 2                     1          65.71          Card
# 3                     8         107.78          Card
# 4                     2         128.45          Card

# %%
order_payments['payment_sequential'].value_counts()
# Out:
# payment_sequential
# 1     99357
# 2      3039
# 3       581
# 4       278
# 5       170
# 6       118
# 7        82
# 8        54
# 9        43
# 10       34
# 11       29
# 12       21
# 13       13
# 14       10
# 15        8
# 17        6
# 19        6
# 16        6
# 18        6
# 21        4
# 20        4
# 22        3
# 25        2
# 26        2
# 24        2
# 23        2
# 27        1
# 29        1
# 28        1
# Name: count, dtype: int64

# %%
order_payments['payment_installments'].value_counts()
# Out:
# payment_installments
# 1     52543
# 2     12413
# 3     10461
# 4      7098
# 10     5328
# 5      5239
# 8      4268
# 6      3920
# 7      1626
# 9       644
# 12      133
# 15       74
# 18       27
# 11       23
# 24       18
# 20       17
# 13       16
# 14       15
# 17        8
# 16        5
# 21        3
# 0         2
# 22        1
# 23        1
# Name: count, dtype: int64

# %%
order_payments['high_installment'] = np.where(
    order_payments['payment_installments'] >= 10,
    1,
    0
)

# %%
order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value payment_group  high_installment
# 0                     8          99.33          Card                 0
# 1                     1          24.39          Card                 0
# 2                     1          65.71          Card                 0
# 3                     8         107.78          Card                 0
# 4                     2         128.45          Card                 0

# %% [markdown]
# # **`Geolocation Dataset`**

# %%
geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
geolocation.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  str
#  4   geolocation_state            1000163 non-null  str
# dtypes: float64(2), int64(1), str(2)
# memory usage: 38.2 MB

# %%
geolocation.isna().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %%
geolocation.duplicated().sum()
# Out:
# np.int64(261831)

# %%
geolocation.drop_duplicates(inplace=True)

# %%
geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
geolocation['geolocation_city'].value_counts()
# Out:
# geolocation_city
# sao paulo                     79927
# rio de janeiro                35177
# são paulo                     19718
# belo horizonte                19474
# curitiba                      11263
#                               ...
# almirante tamandaré do sul        1
# três palmeiras                    1
# são valentim                      1
# três arroios                      1
# ciríaco                           1
# Name: count, Length: 8011, dtype: int64

# %%
geolocation['geolocation_state'].value_counts()
# Out:
# geolocation_state
# SP    285976
# MG    101353
# RJ     78836
# RS     48093
# PR     45059
# SC     30191
# BA     27720
# GO     15601
# PE     13162
# ES     12632
# CE      9541
# MT      9374
# DF      9080
# MS      8594
# PA      8551
# MA      6277
# PB      4787
# RN      4014
# PI      3592
# AL      3415
# TO      2977
# SE      2653
# RO      2523
# AM      1986
# AC      1039
# AP       738
# RR       568
# Name: count, dtype: int64

# %%
for i in geolocation.select_dtypes("number").columns:
  geolocation.boxplot(column=i)
  plt.show()

# %%
geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
geo_summary = (
    geolocation
    .groupby('geolocation_zip_code_prefix')
    .agg({
        'geolocation_lat':'mean',
        'geolocation_lng':'mean'
    })
    .reset_index()
)

# %%
geo_summary.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# 0                         1001       -23.550227       -46.634039
# 1                         1002       -23.547657       -46.634991
# 2                         1003       -23.549000       -46.635582
# 3                         1004       -23.549829       -46.634792
# 4                         1005       -23.549547       -46.636406

# %% [markdown]
# # **`Translation Dataset`**

# %%
translation.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
translation.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     str
#  1   product_category_name_english  71 non-null     str
# dtypes: str(2)
# memory usage: 1.2 KB

# %%
translation.isna().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %%
translation.duplicated().sum()
# Out:
# np.int64(0)

# %%
translation['product_category_name'].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # **`Comparison Tables`**

# %%
translation.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
products = products.merge(
    translation,
    on='product_category_name',
    how='left'
)

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
products['product_category_name_english'].isna().sum()
# Out:
# np.int64(623)

# %%
products.isna().sum()
# Out:
# product_id                         0
# product_category_name              0
# product_name_lenght                0
# product_description_lenght         0
# product_photos_qty                 0
# product_weight_g                   0
# product_length_cm                  0
# product_height_cm                  0
# product_width_cm                   0
# product_volume_cm                  0
# product_category_name_english    623
# dtype: int64

# %% [markdown]
# **Relationships**

# %% [markdown]
# **`Customer → Orders`**

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders['customer_id'].isin(
    customers['customer_id']
).all()
# Out:
# np.True_

# %% [markdown]
# **`Orders → Order Items`**

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  order_value  profit  \
# 0 2017-09-19 09:45:35   58.90          13.29        72.19  10.270
# 1 2017-05-03 11:05:13  239.90          19.93       259.83  76.030
# ...

# %%
order_items['order_id'].isin(
    orders['order_id']
).all()
# Out:
# np.True_

# %% [markdown]
# **`Orders → Reviews`**

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4              Unknown
# 1             5              Unknown
# 2             5              Unknown
# 3             5              Unknown
# 4             5              Unknown
#
#                               review_comment_message review_creation_date  \
# 0                                            Unknown           2018-01-18
# 1                                            Unknown           2018-03-10
# 2                                            Unknown           2018-02-17
# ...

# %%
order_reviews['order_id'].isin(
    orders['order_id']
).all()
# Out:
# np.True_

# %% [markdown]
# **`Orders → Payments`**

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value payment_group  high_installment
# 0                     8          99.33          Card                 0
# 1                     1          24.39          Card                 0
# 2                     1          65.71          Card                 0
# 3                     8         107.78          Card                 0
# 4                     2         128.45          Card                 0

# %%
order_payments['order_id'].isin(
    orders['order_id']
).all()
# Out:
# np.True_

# %% [markdown]
# **`Products → Order Items`**

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  order_value  profit  \
# 0 2017-09-19 09:45:35   58.90          13.29        72.19  10.270
# 1 2017-05-03 11:05:13  239.90          19.93       259.83  76.030
# ...

# %%
order_items['product_id'].isin(
    products['product_id']
).all()
# Out:
# np.True_

# %% [markdown]
# **`Sellers → Order Items`**

# %%
sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  order_value  profit  \
# 0 2017-09-19 09:45:35   58.90          13.29        72.19  10.270
# 1 2017-05-03 11:05:13  239.90          19.93       259.83  76.030
# ...

# %%
order_items['seller_id'].isin(
    sellers['seller_id']
).all()
# Out:
# np.True_

# %% [markdown]
# All returned: True
#
# This means:
#
#       - No orphan records
#       - Referential integrity preserved
#       - Foreign key relationships valid

# %% [markdown]
# **`Created the Dataframe`**

# %%
data_quality = pd.DataFrame({
    'Table': [
        'customers',
        'orders',
        'products',
        'sellers',
        'order_items',
        'order_reviews',
        'order_payments',
        'geolocation',
        'translation'
    ],

    'Rows': [
        customers.shape[0],
        orders.shape[0],
        products.shape[0],
        sellers.shape[0],
        order_items.shape[0],
        order_reviews.shape[0],
        order_payments.shape[0],
        geolocation.shape[0],
        translation.shape[0]
    ],

    'Columns': [
        customers.shape[1],
        orders.shape[1],
        products.shape[1],
        sellers.shape[1],
        order_items.shape[1],
        order_reviews.shape[1],
        order_payments.shape[1],
        geolocation.shape[1],
        translation.shape[1]
    ],

    'Missing Values': [
        customers.isna().sum().sum(),
        orders.isna().sum().sum(),
        products.isna().sum().sum(),
        sellers.isna().sum().sum(),
        order_items.isna().sum().sum(),
        order_reviews.isna().sum().sum(),
        order_payments.isna().sum().sum(),
        geolocation.isna().sum().sum(),
        translation.isna().sum().sum()
    ],

    'Duplicates': [
        customers.duplicated().sum(),
        orders.duplicated().sum(),
        products.duplicated().sum(),
        sellers.duplicated().sum(),
        order_items.duplicated().sum(),
        order_reviews.duplicated().sum(),
        order_payments.duplicated().sum(),
        geolocation.duplicated().sum(),
        translation.duplicated().sum()
    ]
})

data_quality['Missing %'] = (
    data_quality['Missing Values']
    /
    (data_quality['Rows'] * data_quality['Columns'])
    * 100
).round(2)

data_quality
# Out:
#             Table    Rows  Columns  Missing Values  Duplicates  Missing %
# 0       customers   99441        5               0           0       0.00
# 1          orders   99441       15           15758           0       1.06
# 2        products   32951       11             623           0       0.17
# 3         sellers    3095        4               0           0       0.00
# 4     order_items  112650       10               0           0       0.00
# 5   order_reviews   99224        8               0           0       0.00
# 6  order_payments  103883        7               0           0       0.00
# 7     geolocation  738332        5               0           0       0.00
# 8     translation      71        2               0           0       0.00

# %%
data_quality.to_excel(
    'D:/Self-learning/Project/Dataset/cleaned/data_quality_report.xlsx',
    index=False
)

# %% [markdown]
# # **`Feature Engineering`**

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  order_value  profit  \
# 0 2017-09-19 09:45:35   58.90          13.29        72.19  10.270
# 1 2017-05-03 11:05:13  239.90          19.93       259.83  76.030
# ...

# %%
order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value payment_group  high_installment
# 0                     8          99.33          Card                 0
# 1                     1          24.39          Card                 0
# 2                     1          65.71          Card                 0
# 3                     8         107.78          Card                 0
# 4                     2         128.45          Card                 0

# %%
order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4              Unknown
# 1             5              Unknown
# 2             5              Unknown
# 3             5              Unknown
# 4             5              Unknown
#
#                               review_comment_message review_creation_date  \
# 0                                            Unknown           2018-01-18
# 1                                            Unknown           2018-03-10
# 2                                            Unknown           2018-02-17
# ...

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
translation.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
fact_sales = (
    order_items
    .merge(
        orders,
        on='order_id',
        how='left'
    )
)

# %%
fact_sales.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  order_value  profit  \
# 0 2017-09-19 09:45:35   58.90          13.29        72.19  10.270
# 1 2017-05-03 11:05:13  239.90          19.93       259.83  76.030
# ...

# %%
fact_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112650 non-null  str
#  1   order_item_id                  112650 non-null  int64
#  2   product_id                     112650 non-null  str
#  3   seller_id                      112650 non-null  str
#  4   shipping_limit_date            112650 non-null  datetime64[us]
#  5   price                          112650 non-null  float64
#  6   freight_value                  112650 non-null  float64
#  7   order_value                    112650 non-null  float64
#  8   profit                         112650 non-null  float64
#  9   profit_margin                  112650 non-null  float64
#  10  customer_id                    112650 non-null  str
#  11  order_status                   112650 non-null  str
# ...

# %%
fact_sales = (
    fact_sales
    .merge(
        customers,
        on='customer_id',
        how='left'
    )
)

# %%
fact_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112650 non-null  str
#  1   order_item_id                  112650 non-null  int64
#  2   product_id                     112650 non-null  str
#  3   seller_id                      112650 non-null  str
#  4   shipping_limit_date            112650 non-null  datetime64[us]
#  5   price                          112650 non-null  float64
#  6   freight_value                  112650 non-null  float64
#  7   order_value                    112650 non-null  float64
#  8   profit                         112650 non-null  float64
#  9   profit_margin                  112650 non-null  float64
#  10  customer_id                    112650 non-null  str
#  11  order_status                   112650 non-null  str
# ...

# %%
fact_sales = (
    fact_sales
    .merge(
        products,
        on='product_id',
        how='left'
    )
)

# %%
fact_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 38 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112650 non-null  str
#  1   order_item_id                  112650 non-null  int64
#  2   product_id                     112650 non-null  str
#  3   seller_id                      112650 non-null  str
#  4   shipping_limit_date            112650 non-null  datetime64[us]
#  5   price                          112650 non-null  float64
#  6   freight_value                  112650 non-null  float64
#  7   order_value                    112650 non-null  float64
#  8   profit                         112650 non-null  float64
#  9   profit_margin                  112650 non-null  float64
#  10  customer_id                    112650 non-null  str
#  11  order_status                   112650 non-null  str
# ...

# %%
fact_sales = (
    fact_sales
    .merge(
        sellers,
        on='seller_id',
        how='left'
    )
)

# %%
fact_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 41 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112650 non-null  str
#  1   order_item_id                  112650 non-null  int64
#  2   product_id                     112650 non-null  str
#  3   seller_id                      112650 non-null  str
#  4   shipping_limit_date            112650 non-null  datetime64[us]
#  5   price                          112650 non-null  float64
#  6   freight_value                  112650 non-null  float64
#  7   order_value                    112650 non-null  float64
#  8   profit                         112650 non-null  float64
#  9   profit_margin                  112650 non-null  float64
#  10  customer_id                    112650 non-null  str
#  11  order_status                   112650 non-null  str
# ...

# %%
review_summary = (
    order_reviews
    .groupby('order_id')
    .agg({
        'review_score':'mean'
    })
    .reset_index()
)

# %%
review_summary.head()
# Out:
#                            order_id  review_score
# 0  00010242fe8c5a6d1ba2dd792cb16214           5.0
# 1  00018f77f2f0320c557190d7a144bdd3           4.0
# 2  000229ec398224ef6ca0657da4fc703e           5.0
# 3  00024acbcdf0a6daa1e931b038114c75           4.0
# 4  00042b26cf59d7ce69dfabb4e55b4fd9           5.0

# %%
fact_sales = (
    fact_sales
    .merge(
        review_summary,
        on='order_id',
        how='left'
    )
)

# %%
payment_summary = (
    order_payments
    .groupby('order_id')
    .agg({
        'payment_value':'sum'
    })
    .reset_index()
)

# %%
payment_summary.head()
# Out:
#                            order_id  payment_value
# 0  00010242fe8c5a6d1ba2dd792cb16214          72.19
# 1  00018f77f2f0320c557190d7a144bdd3         259.83
# 2  000229ec398224ef6ca0657da4fc703e         216.87
# 3  00024acbcdf0a6daa1e931b038114c75          25.78
# 4  00042b26cf59d7ce69dfabb4e55b4fd9         218.04

# %%
fact_sales = (
    fact_sales
    .merge(
        payment_summary,
        on='order_id',
        how='left'
    )
)

# %%
fact_sales.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  order_value  profit  \
# 0 2017-09-19 09:45:35   58.90          13.29        72.19  10.270
# 1 2017-05-03 11:05:13  239.90          19.93       259.83  76.030
# ...

# %%
fact_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 43 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112650 non-null  str
#  1   order_item_id                  112650 non-null  int64
#  2   product_id                     112650 non-null  str
#  3   seller_id                      112650 non-null  str
#  4   shipping_limit_date            112650 non-null  datetime64[us]
#  5   price                          112650 non-null  float64
#  6   freight_value                  112650 non-null  float64
#  7   order_value                    112650 non-null  float64
#  8   profit                         112650 non-null  float64
#  9   profit_margin                  112650 non-null  float64
#  10  customer_id                    112650 non-null  str
#  11  order_status                   112650 non-null  str
# ...

# %%
fact_sales.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  order_value  profit  \
# 0 2017-09-19 09:45:35   58.90          13.29        72.19  10.270
# 1 2017-05-03 11:05:13  239.90          19.93       259.83  76.030
# ...

# %%
fact_sales['late_delivery'].value_counts()
# Out:
# late_delivery
# On Time    101483
# Late         8714
# Name: count, dtype: int64

# %% [markdown]
# **Order Month**

# %%
fact_sales['order_month'] = (
    fact_sales['order_purchase_timestamp'].dt.month_name()
)

# %%
fact_sales['order_month_num'] = (
    fact_sales['order_purchase_timestamp'].dt.month
)

# %%
fact_sales.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  order_value  profit  \
# 0 2017-09-19 09:45:35   58.90          13.29        72.19  10.270
# 1 2017-05-03 11:05:13  239.90          19.93       259.83  76.030
# ...

# %% [markdown]
# **Order Year**

# %%
fact_sales['order_year'] = (
    fact_sales['order_purchase_timestamp'].dt.year
)

# %% [markdown]
# **Order Quarter**

# %%
fact_sales['order_quarter'] = (
    fact_sales['order_purchase_timestamp'].dt.quarter
)

# %%
fact_sales.groupby('customer_unique_id')['order_id'].nunique()
# Out:
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2    1
# 0000b849f77a49e4a4ce2b2a4ca5be3f    1
# 0000f46a3911fa3c0805444483337064    1
# 0000f6ccb0745a6a4b88665a16c9f078    1
# 0004aac84e0df4da2b147fca70cf8255    1
#                                    ..
# fffcf5a5ff07b0908bd4e2dbc735a684    1
# fffea47cd6d3cc0a88bd621562a9d061    1
# ffff371b4d645b6ecea244b27531430a    1
# ffff5962728ec6157033ef9805bacc48    1
# ffffd2657e2aad2907e67c3e9daecbeb    1
# Name: order_id, Length: 95420, dtype: int64

# %%
customer_orders = (
    fact_sales
    .groupby('customer_unique_id')
    ['order_id']
    .nunique()
)

# %%
fact_sales['customer_type'] = np.where(
    fact_sales['customer_unique_id']
    .map(customer_orders)
    > 1,
    'Repeat',
    'New'
)

# %%
fact_sales.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  order_value  profit  \
# 0 2017-09-19 09:45:35   58.90          13.29        72.19  10.270
# 1 2017-05-03 11:05:13  239.90          19.93       259.83  76.030
# ...

# %%
fact_sales.shape
# Out:
# (112650, 48)

# %%
fact_sales.isnull().sum()
# Out:
# order_id                            0
# order_item_id                       0
# product_id                          0
# seller_id                           0
# shipping_limit_date                 0
# price                               0
# freight_value                       0
# order_value                         0
# profit                              0
# profit_margin                       0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                  15
# order_delivered_carrier_date     1194
# order_delivered_customer_date    2454
# order_estimated_delivery_date       0
# delivery_days                    2454
# estimate_delivery_days              0
# approval_hours                     15
# carrier_pickup_days              1209
# late_delivery                    2453
# delivery_variance_days           2454
# pickup_date_issue                   0
# customer_unique_id                  0
# ...

# %%
fact_sales.isnull().sum().sort_values(
    ascending=False
).head(20)
# Out:
# order_delivered_customer_date    2454
# delivery_days                    2454
# delivery_variance_days           2454
# late_delivery                    2453
# product_category_name_english    1627
# carrier_pickup_days              1209
# order_delivered_carrier_date     1194
# review_score                      942
# order_approved_at                  15
# approval_hours                     15
# payment_value                       3
# order_id                            0
# shipping_limit_date                 0
# order_item_id                       0
# product_id                          0
# seller_id                           0
# order_purchase_timestamp            0
# profit_margin                       0
# customer_id                         0
# order_status                        0
# dtype: int64

# %%
fact_sales.duplicated().sum()
# Out:
# np.int64(0)

# %%
fact_sales[
    ['order_id','order_item_id']
].duplicated().sum()
# Out:
# np.int64(0)

# %%
fact_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 48 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112650 non-null  str
#  1   order_item_id                  112650 non-null  int64
#  2   product_id                     112650 non-null  str
#  3   seller_id                      112650 non-null  str
#  4   shipping_limit_date            112650 non-null  datetime64[us]
#  5   price                          112650 non-null  float64
#  6   freight_value                  112650 non-null  float64
#  7   order_value                    112650 non-null  float64
#  8   profit                         112650 non-null  float64
#  9   profit_margin                  112650 non-null  float64
#  10  customer_id                    112650 non-null  str
#  11  order_status                   112650 non-null  str
# ...

# %%
fact_sales.value_counts()
# Out:
# order_id                          order_item_id  product_id                        seller_id                         shipping_limit_date  price   freight_value  order_value  profit    profit_margin  customer_id                       order_status  order_purchase_timestamp  order_approved_at    order_delivered_carrier_date  order_delivered_customer_date  order_estimated_delivery_date  delivery_days  estimate_delivery_days  approval_hours  carrier_pickup_days  late_delivery  delivery_variance_days  pickup_date_issue  customer_unique_id                customer_zip_code_prefix  customer_city          customer_state  product_category_name   product_name_lenght  product_description_lenght  product_photos_qty  product_weight_g  product_length_cm  product_height_cm  product_width_cm  product_volume_cm  product_category_name_english  seller_zip_code_prefix  seller_city    seller_state  review_score  payment_value  order_month  order_month_num  order_year  order_quarter  customer_type
# ...

# %%
fact_sales.to_csv(
    'D:/Self-learning/Project/Dataset/cleaned/fact_sales.csv',
    index=False
)

# %% [markdown]
# **Star Schema**
# --------------------------------------------------------
# --------------------------------------------------------

# %% [markdown]
# order table
# --------------------------
#     order_id
#     order_item_id
#     order_value
#     order_status
#     order_purchase_timestamp
#     order_approved_at
#     order_delivered_carrier_date
#     order_delivered_customer_date
#     order_estimated_delivery_date
#     order_month
#     order_month_num
#     order_year
#     order_quarter
#
#
#
#
# product table
# -----------------
#     product_id
#     product_category_name
#     product_name_lenght
#     product_description_lenght
#     product_photos_qty
#     product_weight_g
#     product_length_cm
#     product_height_cm
#     product_width_cm
#     product_volume_cm
#     product_category_name_english
#
#
# seller table
# --------------
#     seller_id
#     seller_zip_code_prefix
#     seller_city
#     seller_state
#
#
# customer table
# -------------------
#     customer_id
#     customer_unique_id
#     customer_zip_code_prefix
#     customer_city
#     customer_state
#     customer_type
#
#
#
# date
# -------
#     shipping_limit_date
#     delivery_days
#     estimate_delivery_days
#     approval_hours
#     carrier_pickup_days
#     late_delivery
#     delivery_variance_days
#     pickup_date_issue
#
#
# other
# -------
#
#     price
#     freight_value
#     profit
#     profit_margin
#     review_score
#     payment_value

# %% [markdown]
# **Customer Dimension**

# %%
dim_customer = fact_sales[
[
'customer_id',
'customer_unique_id',
'customer_zip_code_prefix',
'customer_city',
'customer_state',
'customer_type'
]
].drop_duplicates()



dim_customer.to_csv(
'D:/Self-learning/Project/Dataset/cleaned/dim_customer.csv',
index=False
)

# %%
dim_customer.shape
# Out:
# (98666, 6)

# %% [markdown]
# **Product Dimension**

# %%
dim_product = fact_sales[
[
'product_id',
'product_category_name',
'product_category_name_english',
'product_name_lenght',
'product_description_lenght',
'product_photos_qty',
'product_weight_g',
'product_length_cm',
'product_height_cm',
'product_width_cm',
'product_volume_cm'
]
].drop_duplicates()



dim_product.to_csv(
'D:/Self-learning/Project/Dataset/cleaned/dim_product.csv',
index=False
)

# %%
dim_product.shape
# Out:
# (32951, 11)

# %% [markdown]
# **Seller Dimension**

# %%
dim_seller = fact_sales[
[
'seller_id',
'seller_zip_code_prefix',
'seller_city',
'seller_state'
]
].drop_duplicates()



dim_seller.to_csv(
'D:/Self-learning/Project/Dataset/cleaned/dim_seller.csv',
index=False
)

# %%
dim_seller.shape
# Out:
# (3095, 4)

# %% [markdown]
# **Date Dimension**

# %%
date_range = pd.date_range(
    start=fact_sales['order_purchase_timestamp'].min().date(),
    end=fact_sales['order_purchase_timestamp'].max().date(),
    freq='D'
)

# %%
dim_date = pd.DataFrame()

# %%
dim_date['date_key'] = date_range

dim_date['day_num'] = date_range.day.astype(int)

dim_date['month_num'] = date_range.month.astype(int)

dim_date['month_name'] = date_range.month_name()

dim_date['quarter_num'] = date_range.quarter.astype(int)

dim_date['year_num'] = date_range.year.astype(int)

dim_date['week_num'] = (
    date_range.isocalendar().week.astype(int).values
)

dim_date['weekday_name'] = date_range.day_name()

# %%
dim_date.head()
# Out:
#     date_key  day_num  month_num month_name  quarter_num  year_num  week_num  \
# 0 2016-09-04        4          9  September            3      2016        35
# 1 2016-09-05        5          9  September            3      2016        36
# 2 2016-09-06        6          9  September            3      2016        36
# 3 2016-09-07        7          9  September            3      2016        36
# 4 2016-09-08        8          9  September            3      2016        36
#
#   weekday_name
# 0       Sunday
# 1       Monday
# 2      Tuesday
# 3    Wednesday
# 4     Thursday

# %%
dim_date.isnull().sum()
# Out:
# date_key        0
# day_num         0
# month_num       0
# month_name      0
# quarter_num     0
# year_num        0
# week_num        0
# weekday_name    0
# dtype: int64

# %%
dim_date.to_csv(
'D:/Self-learning/Project/Dataset/cleaned/dim_date.csv',
index=False
)

# %%
dim_date.shape
# Out:
# (730, 8)

# %% [markdown]
# **Fact Table File**

# %%
fact_sales_dw = fact_sales[
[
'order_id',
'order_item_id',

'customer_id',
'product_id',
'seller_id',

'order_purchase_timestamp',

'shipping_limit_date',

'order_approved_at',

'order_delivered_carrier_date',

'order_delivered_customer_date',

'order_estimated_delivery_date',

'order_status',

'price',
'freight_value',
'payment_value',
'order_value',

'profit',
'profit_margin',

'delivery_days',
'estimate_delivery_days',

'approval_hours',
'carrier_pickup_days',

'late_delivery',
'delivery_variance_days',

'pickup_date_issue',

'review_score'
]
]

# %%
fact_sales_dw.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       112650 non-null  str
#  1   order_item_id                  112650 non-null  int64
#  2   customer_id                    112650 non-null  str
#  3   product_id                     112650 non-null  str
#  4   seller_id                      112650 non-null  str
#  5   order_purchase_timestamp       112650 non-null  datetime64[us]
#  6   shipping_limit_date            112650 non-null  datetime64[us]
#  7   order_approved_at              112635 non-null  datetime64[us]
#  8   order_delivered_carrier_date   111456 non-null  datetime64[us]
#  9   order_delivered_customer_date  110196 non-null  datetime64[us]
#  10  order_estimated_delivery_date  112650 non-null  datetime64[us]
# ...

# %%
fact_sales_dw.isna().sum()
# Out:
# order_id                            0
# order_item_id                       0
# customer_id                         0
# product_id                          0
# seller_id                           0
# order_purchase_timestamp            0
# shipping_limit_date                 0
# order_approved_at                  15
# order_delivered_carrier_date     1194
# order_delivered_customer_date    2454
# order_estimated_delivery_date       0
# order_status                        0
# price                               0
# freight_value                       0
# payment_value                       3
# order_value                         0
# profit                              0
# profit_margin                       0
# delivery_days                    2454
# estimate_delivery_days              0
# approval_hours                     15
# carrier_pickup_days              1209
# late_delivery                    2453
# delivery_variance_days           2454
# pickup_date_issue                   0
# ...

# %%
fact_sales_dw.to_csv(
'D:/Self-learning/Project/Dataset/cleaned/fact_sales_dw.csv',
index=False

)

# %%
fact_sales_dw.shape
# Out:
# (112650, 26)
